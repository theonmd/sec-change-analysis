# %% [markdown]
# # Final analysis of large cap companies and first results

# %%
# %pip install -U sec-edgar-downloader | grep -v 'already satisfied' 
# %pip install yfinance | grep -v 'already satisfied'
# %pip install pandas_datareader | grep -v 'already satisfied' 
# %pip install cleantext | grep -v 'already satisfied'
# %pip install ipynb | grep -v 'already satisfied'

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import ipynb
import pickle
import os

# %run A_data_extraction.ipynb
# %run I_data_pre_processing.ipynb
# %run II_models.ipynb
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: w3lib in /Users/theolanganay/opt/anaconda3/lib/python3.9/site-packages (1.22.0)
# Requirement already satisfied: six>=1.4.1 in /Users/theolanganay/opt/anaconda3/lib/python3.9/site-packages (from w3lib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
def comparisons(tkrs, n, plot = False):
    '''
    Function that takes as input a list of tickers and a number of years to perform the comparison on
    Performs comparisons for all companies in the list and saves the scores as a pickle file
    '''
    sim_dic = {}
    for tick in tkrs:
        print('Working on {}'.format(tick))
        # Download raw files and create folders for each company (A_data_extraction.ipynb)
        files_downloader("10-K", str(tick), n = n)
        
        # Clean the previously downloaded files and store them in the clean folder (I_data_pre_processing.ipynb)
        # Create the compnay object
        comp_files = files_cleaning(tick)
        # Create the clean files
        comp_files.write_clean_files()
        
        # Compute similarities (II_models.ipynb)
        print('Computing similarities...')
        comp_sim = similarities(tick)
        comp_df = comp_sim.compute_sim('01', 'tfidf')
        sim_dic[tick] = comp_df
        
        if plot:
            sns.kdeplot(data = comp_sim, x = 'tfidf_cosine_sim')
            plt.show()
            
        
        # Save the company's similarities
        save_path = './data/{}/{}_similarities.pickle'.format(tick, tick)
        with open(save_path, 'wb') as handle:
            pickle.dump(comp_df, handle, protocol=pickle.HIGHEST_PROTOCOL)
            
        print('Done with {}!'.format(tick))
        print('--------------------------')
    
    # Save the similarities as pickle file
    save_path = './data/similarities.pickle'
    with open(save_path, 'wb') as handle:
        pickle.dump(sim_dic, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
def clean_all():
    '''
    Function that removes all files to rerun next step
    '''
    for tick in os.listdir('./data'):
        clean_path = os.path.join('./data', tick, 'clean')
        raw_path = os.path.join('./data', tick, 'raw')
        
        if os.path.exists(raw_path):
            for f in os.listdir(raw_path):
                if not f[0] == '.':
                    os.remove(os.path.join(raw_path, f))  

        if os.path.exists(clean_path):
            for f in os.listdir(clean_path):
                if not f[0] == '.':
                    os.remove(os.path.join(clean_path, f))

# %%
clean_all()

# %%
tickers_df = pd.read_csv('./data/stock_tickers.csv', sep = ';')[['ticker']]
tickers = list(tickers_df.ticker.values)

# %%
comparisons(tickers[1:60], n = 20)
# Out:
# Working on MSFT
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with MSFT!
# --------------------------
# Working on GOOG
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with GOOG!
# --------------------------
# Working on TSLA
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with TSLA!
# --------------------------
# Working on UNH
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with UNH!
# --------------------------
# Working on JNJ
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with JNJ!
# --------------------------
# Working on FB
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with FB!
# --------------------------
# Working on NVDA
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with NVDA!
# --------------------------
# Working on V
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with V!
# --------------------------
# Working on WMT
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with WMT!
# --------------------------
# Working on PG
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with PG!
# --------------------------
# Working on JPM
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with JPM!
# --------------------------
# Working on XOM
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with XOM!
# --------------------------
# Working on MA
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with MA!
# --------------------------
# Working on HD
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with HD!
# --------------------------
# Working on CVX
# Skipping filing detail download for '0000093410-01-000015' due to network error: 404 Client Error: Not Found for url: https://www.sec.gov/Archives/edgar/data/0000093410/000009341001000015/0001.txt.
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with CVX!
# --------------------------
# Working on BAC
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with BAC!
# --------------------------
# Working on KO
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with KO!
# --------------------------
# Working on ABBV
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with ABBV!
# --------------------------
# Working on PFE
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with PFE!
# --------------------------
# Working on LLY
# Skipping filing detail download for '0000950131-01-001634' due to network error: 404 Client Error: Not Found for url: https://www.sec.gov/Archives/edgar/data/0000059478/000095013101001634/0001.htm.
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with LLY!
# --------------------------
# Working on COST
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with COST!
# --------------------------
# Working on PEP
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with PEP!
# --------------------------
# Working on AVGO
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with AVGO!
# --------------------------
# Working on MRK
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with MRK!
# --------------------------
# Working on DIS
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with DIS!
# --------------------------
# Working on CSCO
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with CSCO!
# --------------------------
# Working on VZ
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with VZ!
# --------------------------
# Working on ABT
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with ABT!
# --------------------------
# Working on TMO
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with TMO!
# --------------------------
# Working on CMCSA
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with CMCSA!
# --------------------------
# Working on ORCL
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with ORCL!
# --------------------------
# Working on ACN
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with ACN!
# --------------------------
# Working on NKE
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with NKE!
# --------------------------
# Working on ADBE
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with ADBE!
# --------------------------
# Working on INTC
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with INTC!
# --------------------------
# Working on MCD
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with MCD!
# --------------------------
# Working on DHR
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with DHR!
# --------------------------
# Working on CRM
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with CRM!
# --------------------------
# Working on WFC
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with WFC!
# --------------------------
# Working on TMUS
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with TMUS!
# --------------------------
# Working on UPS
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with UPS!
# --------------------------
# Working on BMY
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with BMY!
# --------------------------
# Working on PM
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with PM!
# --------------------------
# Working on LIN
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with LIN!
# --------------------------
# Working on TXN
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with TXN!
# --------------------------
# Working on QCOM
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with QCOM!
# --------------------------
# Working on UNP
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with UNP!
# --------------------------
# Working on RTX
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with RTX!
# --------------------------
# Working on MS
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with MS!
# --------------------------
# Working on NEE
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with NEE!
# --------------------------
# Working on MDT
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with MDT!
# --------------------------
# Working on T
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with T!
# --------------------------
# Working on AMD
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with AMD!
# --------------------------
# Working on AXP
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with AXP!
# --------------------------
# Working on LOW
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with LOW!
# --------------------------
# Working on AMGN
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with AMGN!
# --------------------------
# Working on CVS
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with CVS!
# --------------------------
# Working on SPGI
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with SPGI!
# --------------------------
# Working on SCHW
# Extracting textual content...
# Cleaning the text (might take long)...
# Writing the clean files...
# Computing similarities...
# Done with SCHW!
# --------------------------
